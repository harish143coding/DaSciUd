# %%
import pandas as pd
import dtale

# %%
accidents_bremen_2019 = pd.read_table("Reduzierter Datensatz_Fahrrad-VU_2019_StadtBremen.txt")

# %%
accidents_bremen_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1477 entries, 0 to 1476
# Data columns (total 40 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LfNr           1477 non-null   int64
#  1   Datum          1477 non-null   object
#  2   Zeit           1477 non-null   object
#  3   WoTag          1477 non-null   object
#  4   Kl             1477 non-null   int64
#  5   NrBu           15 non-null     float64
#  6   Gemeinde       1473 non-null   object
#  7   Strasse        1476 non-null   object
#  8   Gt             1477 non-null   int64
#  9   Sv             1477 non-null   int64
#  10  Lv             1477 non-null   int64
#  11  Bet            1477 non-null   int64
#  12  Art            1477 non-null   int64
#  13  Char1          724 non-null    float64
#  14  Char2          11 non-null     float64
#  15  Beso1          233 non-null    float64
#  16  Beso2          9 non-null      float64
#  17  Beso3          0 non-null      float64
#  18  LZ             168 non-null    float64
#  19  Kat            1477 non-null   int64
#  20  Typ            1477 non-null   int64
#  21  UTyp           0 non-null      float64
#  22  1Urs01         1473 non-null   float64
#  23  1Urs02         169 non-null    float64
#  24  2Urs01         195 non-null    float64
#  25  2Urs02         7 non-null      float64
#  26  AUrs01         198 non-null    float64
#  27  AV1            1477 non-null   int64
#  28  AV2            1329 non-null   float64
#  29  Jahr           1477 non-null   int64
#  30  Mt             1477 non-null   int64
#  31  Tag            1477 non-null   int64
#  32  Licht          1477 non-null   object
#  33  Str_Zus        1477 non-null   object
#  34  Bet_01         1477 non-null   object
#  35  Bet_02         1477 non-null   object
#  36  Unf_Typ        1477 non-null   object
#  37  Fahrtrichtung  3 non-null      object
#  38  Koord.x        1477 non-null   object
#  39  Koord.y        1477 non-null   object
# dtypes: float64(14), int64(13), object(13)
# memory usage: 461.7+ KB

# %%
# performing EDA to get the insights of the data
eda_accident_data = dtale.show(accidents_bremen_2019)
# Out:
# /home/harish/GitRepos/DaSciUd/venv/lib/python3.8/site-packages/dtale/views.py:725: FutureWarning:
#
# ['Gemeinde', 'Strasse', 'Fahrtrichtung'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.

# %% [markdown]
# #### Data understanding

# %%
# returns whether series/DataFrame is empty in boolean form
accidents_bremen_2019.empty
accidents_bremen_2019["2Urs01"].empty
# Out:
# False

# %%
# returns the subset of dataframe columns datatypes 
accidents_bremen_2019.select_dtypes(include="float64")

# %%
#accidents_bremen_2019.plot.pie(subplots=True, figsize=(11, 6))

# %%
#accidents_bremen_2019.groupby(['Gemeinde', 'Strasse', 'Sv']).apply('sum')

# %%
accidents_bremen_2019["Gt"].value_counts()
# Out:
# 0    1474
# 1       3
# Name: Gt, dtype: int64

# %%
df_english_columns = accidenvalue_countsbentbremen_2019.rename(
                     {
                         "Gt" : "died",
                         "Sv" : "severly_injured",
                         "Lv" : "light injury",
                         "Bet":  "involoved_parties",
                         "Art":  "type",
                         "Char1": "",
                         "Char2": "",
                         "Beso1": "peculiarity1",
                         "Beso2": "peculiarity2",
                         
                         
                     
                     }
)

# %% [markdown]
# ## plan of action for the accident data (Unfall Daten)
# #### description of the available data
# __idea__
#
# *focus on the particular street where the smarthelm experiments will be carried out.*
#
# *set markers on the street from the data obtained between 2019 to 2021*
#
# *integrate them on to the map*
